# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

data = pd.read_csv (r'RKI_COVID19.csv')

# %%
data.head()
# Out:
#         FID  IdBundesland          Bundesland     Landkreis Altersgruppe  \
# 0  43821735             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 1  43821736             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 2  43821737             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 3  43821738             1  Schleswig-Holstein  SK Flensburg      A05-A14
# 4  43821739             1  Schleswig-Holstein  SK Flensburg      A05-A14
#
#   Geschlecht  AnzahlFall  AnzahlTodesfall           Meldedatum  IdLandkreis  \
# 0          M           1                0  2020/09/30 00:00:00         1001
# 1          W           1                0  2020/08/24 00:00:00         1001
# 2          W           1                0  2020/09/26 00:00:00         1001
# 3          M           1                0  2020/09/25 00:00:00         1001
# 4          M           1                0  2020/09/26 00:00:00         1001
#
#               Datenstand  NeuerFall  NeuerTodesfall             Refdatum  \
# 0  14.10.2020, 00:00 Uhr          0              -9  2020/09/30 00:00:00
# 1  14.10.2020, 00:00 Uhr          0              -9  2020/08/24 00:00:00
# 2  14.10.2020, 00:00 Uhr          0              -9  2020/09/26 00:00:00
# 3  14.10.2020, 00:00 Uhr          0              -9  2020/09/21 00:00:00
# 4  14.10.2020, 00:00 Uhr          0              -9  2020/09/21 00:00:00
#
#    NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn      Altersgruppe2
# 0           1              1                     0  Nicht übermittelt
# 1           0              1                     0  Nicht übermittelt
# 2           0              1                     0  Nicht übermittelt
# 3           0              1                     1  Nicht übermittelt
# 4           0              1                     1  Nicht übermittelt

# %%
ct_df = data[["AnzahlFall", "Meldedatum"]]
ct_df[["Date","Uhrzeit"]] = ct_df["Meldedatum"].str.split(" ", expand = True)
ct_df["Date"]= pd.DatetimeIndex(ct_df['Date']) 
ct_df_sum = ct_df.groupby("Date").sum()  

date_column = pd.Series(np.arange(ct_df.min().Date, ct_df.max().Date, dtype='datetime64[D]')) 
step0 = date_column.to_frame().rename(columns={0:"Date"})
step0.reset_index(drop = True).set_index("Date")

step1 = (pd.merge(step0, ct_df, how="outer",left_on="Date", right_on="Date")).set_index("Date")
# Out:
# 0     2020-01-28
# 1     2020-01-29
# 2     2020-01-30
# 3     2020-01-31
# 4     2020-02-01
#          ...
# 254   2020-10-08
# 255   2020-10-09
# 256   2020-10-10
# 257   2020-10-11
# 258   2020-10-12
# Length: 259, dtype: datetime64[ns]
# Empty DataFrame
# Columns: []
